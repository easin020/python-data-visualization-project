# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\User\\Downloads\\m35 (1).csv")

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df["TotalQty(EA)"]= df["Total Qty(Ea)"]
df.drop("Total Qty(Ea)",axis = 1,inplace=True)

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df["TotalQty(EA)"]= df["TotalQty(EA)"].str.split(" ").str.get(0)
df["TotalQty(EA)"]= df["TotalQty(EA)"].str.split(".").str.get(0)
df["TotalQty(EA)"]= df["TotalQty(EA)"].str.replace(",","").astype(float)

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.fillna(0)
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.describe()
# Out:
#        Cal. year / month  Sold-to party  Ship-To Party  TotalQty(EA)
# count       4.917000e+03    4917.000000   4.917000e+03   4917.000000
# mean        7.202200e+00   68585.625381   4.542651e+06     58.867399
# std         2.380560e-13   39142.366879   6.674247e+07    344.908292
# min         7.202200e+00     157.000000   1.570000e+02  -1000.000000
# 25%         7.202200e+00   45851.000000   4.585200e+04      1.000000
# 50%         7.202200e+00   75560.000000   7.586800e+04      3.000000
# 75%         7.202200e+00  104769.000000   1.050200e+05     12.000000
# max         7.202200e+00  124728.000000   1.000001e+09  11430.000000

# %%
df["SalesValue(AED)"]= df["SalesValue"]
df.drop("SalesValue",axis = 1,inplace=True)

# %%
df["SalesValue(AED)"]= df["SalesValue(AED)"].str.split(" ").str.get(0)
df["SalesValue(AED)"]= df["SalesValue(AED)"].str.split(".").str.get(0)
df["SalesValue(AED)"]= df["SalesValue(AED)"].str.replace(",","").astype(float)

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df["SalesQty(EA)"]= df["SalesQty"]
df.drop("SalesQty",axis = 1,inplace=True)

# %%
df["SalesQty(EA)"]= df["SalesQty(EA)"].str.split(" ").str.get(0)
df["SalesQty(EA)"]= df["SalesQty(EA)"].str.split(".").str.get(0)
df["SalesQty(EA)"]= df["SalesQty(EA)"].str.replace(",","").astype(float)

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df["FocQty(EA)"]= df["FocQty"]
df.drop("FocQty",axis = 1,inplace=True)

# %%
df["FocQty(EA)"]= df["FocQty(EA)"].str.split(" ").str.get(0)
df["FocQty(EA)"]= df["FocQty(EA)"].str.split(".").str.get(0)
df["FocQty(EA)"]= df["FocQty(EA)"].str.replace(",","").astype(float)

# %%
df.fillna(0)
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.describe()
# Out:
#        Cal. year / month  Sold-to party  Ship-To Party  TotalQty(EA)  \
# count       4.917000e+03    4917.000000   4.917000e+03   4917.000000
# mean        7.202200e+00   68585.625381   4.542651e+06     58.867399
# std         2.380560e-13   39142.366879   6.674247e+07    344.908292
# min         7.202200e+00     157.000000   1.570000e+02  -1000.000000
# 25%         7.202200e+00   45851.000000   4.585200e+04      1.000000
# 50%         7.202200e+00   75560.000000   7.586800e+04      3.000000
# 75%         7.202200e+00  104769.000000   1.050200e+05     12.000000
# max         7.202200e+00  124728.000000   1.000001e+09  11430.000000
#
#        SalesValue(AED)  SalesQty(EA)  FocQty(EA)
# count      4896.000000   4896.000000  304.000000
# mean       6262.735907     57.216299   30.657895
# std       31376.704984    336.922564   72.845522
# min     -188054.000000  -1000.000000  -96.000000
# 25%          54.000000      1.000000    2.000000
# ...
